# %%
import numpy as np
import os
from scipy.io import savemat
import pandas as pd
from pathlib import Path

# %%
with np.load('C:\\Users\\ldd77\\clustering_neuron_spikes_with_deep_learning\\Default_Results_Dir\\firings.npz') as data:
    print(data.files) 
    print(data['spike_labels_seg0'])
    spike_lavbels = data['spike_labels_seg0']
    spike_times = data['spike_indexes_seg0']
# Out:
# ['unit_ids', 'num_segment', 'sampling_frequency', 'spike_indexes_seg0', 'spike_labels_seg0']
# [358 479  54 ... 355 392 129]
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[10], line 5
#       3 print(data['spike_labels_seg0'])
#       4 spike_lavbels = data['spike_labels_seg0']
# ----> 5 spike_times = data['spike_times_seg0']
#
# File c:\Users\ldd77\clustering_neuron_spikes_with_deep_learning\ss_env312\Lib\site-packages\numpy\lib\npyio.py:263, in NpzFile.__getitem__(self, key)
#     261         return self.zip.read(key)
#     262 else:
# --> 263     raise KeyError(f"{key} is not a file in the archive")
#
# KeyError: 'spike_times_seg0 is not a file in the archive'

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 data['spike_labels_seg0']
#
# File c:\Users\ldd77\clustering_neuron_spikes_with_deep_learning\ss_env312\Lib\site-packages\numpy\lib\npyio.py:251, in NpzFile.__getitem__(self, key)
#     249     key += '.npy'
#     250 if member:
# --> 251     bytes = self.zip.open(key)
#     252     magic = bytes.read(len(format.MAGIC_PREFIX))
#     253     bytes.close()
#
# AttributeError: 'NoneType' object has no attribute 'open'
