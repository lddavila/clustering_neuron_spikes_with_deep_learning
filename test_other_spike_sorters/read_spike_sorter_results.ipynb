# %%
from spikeinterface import extractors
from spikeinterface.extractors import read_mda_sorting
import os
import glob

# %%
#read the raw.mda file into the spikeinterface extractor
dataset_dir = r"C:\Users\ldd77\clustering_neuron_spikes_with_deep_learning\Default_Results_Dir\recording_10_other_ss\ironclust_output\sorter_output\ironclust_dataset"
firings_fp = r"C:\Users\ldd77\clustering_neuron_spikes_with_deep_learning\Default_Results_Dir\recording_10_other_ss\ironclust_output\sorter_output\tmp\firings.mda"
sorting = read_mda_sorting(firings_fp, sampling_frequency=30000)

# %%
sorting.get_unit_ids()
sorting.get_unit_spike_train(unit_id=1)  # get spike train for unit 1
sorting.get_unit_spike_train_in_seconds(unit_id=1)  # get spike train in seconds for unit 1
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[27], line 4
#       2 sorting.get_unit_spike_train(unit_id=1)  # get spike train for unit 1
#       3 sorting.get_unit_spike_train_in_seconds(unit_id=1)  # get spike train in seconds for unit 1
# ----> 4 sorting.sorting_info()
#
# TypeError: 'NoneType' object is not callable
